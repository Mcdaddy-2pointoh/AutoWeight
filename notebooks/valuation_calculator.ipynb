# %% [markdown]
# # 0. Configs and Imports

# %% [markdown]
# ## 0.1. Imports

# %%
# External Libraries imports
import pandas as pd

# Specialised imports
from src.utils.file_operators import load_yaml
from src.computation.valuation import raw_valuation_score_computation

# %% [markdown]
# ## 0.2. Configuration Filepath & Configuration Dictionary

# %%
conf_path = "C:/Users/sharv/Documents/Sharvil/Projects/AutoWeight/config-sd.yaml"

# %%
config = load_yaml(conf_path)

# %% [markdown]
# # 1. View the Tickers & set configuration

# %%
# Print the tickers defined in the config
ticker_list = config['config']['data']['tickers']

# Print the window and volitility_indicator defined in the config
window = config['config']['data']['window_in_days']
volatility_indicator = config['config']['data']['vix']

# %%
print("The tickers in the config list are:")

for idx, ticker in enumerate(ticker_list):
    print(f"    {idx+1}. {ticker}")

print(f"The window of data to evaluate is `{window}` days")

print(f"The volatility indicator used is `{volatility_indicator}`")
# Out:
# The tickers in the config list are:
#     1. HDFCSML250.NS
#     2. HDFCGOLD.NS
#     3. HDFCNEXT50.NS
# The window of data to evaluate is `900` days
# The volatility indicator used is `^INDIAVIX`

# %% [markdown]
# # 2. View the Correlation Parameters from Data

# %%
config['config']['parameters']['valuation']
# Out:
# {'method': 'log_price_z_score',
#  'window_in_days': 400,
#  'metric': 'adj_close',
#  'clip': 0.0001,
#  'apply_bounding': True}

# %% [markdown]
# # 3. Calculate Valuation Values

# %%
valuation_results = raw_valuation_score_computation(
    config_path=conf_path,
    save_data=False,
    verbose=True
)
# Out:
# INFO: Starting Valuation Pipeline.
# INFO: Using price metric adj_close
# INFO: Computing Valuation scores:
# INFO:     Computing valuation score for column: log_price_HDFCNEXT50.NS
# WARN: No variation in valuation score observed for log_price_HDFCNEXT50.NS. For a robust calculation re-run the valuation pipeline with percentile_dispersion flag in [parameters -> valuation] as 'True'
# INFO:     Computing valuation score for column: log_price_HDFCSML250.NS
# WARN: No variation in valuation score observed for log_price_HDFCSML250.NS. For a robust calculation re-run the valuation pipeline with percentile_dispersion flag in [parameters -> valuation] as 'True'
# INFO:     Computing valuation score for column: log_price_HDFCGOLD.NS
# WARN: No variation in valuation score observed for log_price_HDFCGOLD.NS. For a robust calculation re-run the valuation pipeline with percentile_dispersion flag in [parameters -> valuation] as 'True'
# SUCCESS: Valuation Pipeline Run Successfully.

# %%
valuation_results['valuation_score_df']
# Out:
#             price_HDFCSML250.NS  price_HDFCGOLD.NS  price_HDFCNEXT50.NS  \
# Date
# 2025-03-12           142.779999          74.480003            60.090000
# 2025-03-13           141.869995          74.889999            59.779999
# 2025-03-17           142.259995          75.699997            60.169998
# 2025-03-18           142.259995          76.300003            60.169998
# 2025-03-19           148.960007          76.360001            62.750000
# ...                         ...                ...                  ...
# 2025-12-29           166.169998         116.870003            69.730003
# 2025-12-30           165.929993         114.940002            69.949997
# 2025-12-31           167.710007         113.709999            70.599998
# 2026-01-01           167.529999         114.099998            70.959999
# 2026-01-02           168.850006         115.449997            71.489998
#
#             log_price_HDFCSML250.NS  log_price_HDFCGOLD.NS  \
# Date
# 2025-03-12                 4.961305               4.310531
# 2025-03-13                 4.954911               4.316020
# 2025-03-17                 4.957656               4.326778
# 2025-03-18                 4.957656               4.334673
# 2025-03-19                 5.003678               4.335459
# ...                             ...                    ...
# 2025-12-29                 5.113011               4.761062
# 2025-12-30                 5.111566               4.744410
# 2025-12-31                 5.122236               4.733651
# 2026-01-01                 5.121162               4.737075
# 2026-01-02                 5.129011               4.748838
#
#             log_price_HDFCNEXT50.NS  \
# Date
# 2025-03-12                 4.095843
# 2025-03-13                 4.090671
# 2025-03-17                 4.097174
# 2025-03-18                 4.097174
# 2025-03-19                 4.139159
# ...                             ...
# 2025-12-29                 4.244631
# 2025-12-30                 4.247781
# 2025-12-31                 4.257030
# 2026-01-01                 4.262116
# 2026-01-02                 4.269558
#
#             bounded_valuation_score_log_price_HDFCNEXT50.NS  \
# Date
# 2025-03-12                                             -1.0
# 2025-03-13                                             -1.0
# 2025-03-17                                             -1.0
# 2025-03-18                                             -1.0
# 2025-03-19                                             -1.0
# ...                                                     ...
# 2025-12-29                                             -1.0
# 2025-12-30                                             -1.0
# 2025-12-31                                             -1.0
# 2026-01-01                                             -1.0
# 2026-01-02                                             -1.0
#
#             valuation_score_log_price_HDFCNEXT50.NS  \
# Date
# 2025-03-12                                   0.0001
# 2025-03-13                                   0.0001
# 2025-03-17                                   0.0001
# 2025-03-18                                   0.0001
# 2025-03-19                                   0.0001
# ...                                             ...
# 2025-12-29                                   0.0001
# 2025-12-30                                   0.0001
# 2025-12-31                                   0.0001
# 2026-01-01                                   0.0001
# 2026-01-02                                   0.0001
#
#             bounded_valuation_score_log_price_HDFCSML250.NS  \
# Date
# 2025-03-12                                             -1.0
# 2025-03-13                                             -1.0
# 2025-03-17                                             -1.0
# 2025-03-18                                             -1.0
# 2025-03-19                                             -1.0
# ...                                                     ...
# 2025-12-29                                             -1.0
# 2025-12-30                                             -1.0
# 2025-12-31                                             -1.0
# 2026-01-01                                             -1.0
# 2026-01-02                                             -1.0
#
#             valuation_score_log_price_HDFCSML250.NS  \
# Date
# 2025-03-12                                   0.0001
# 2025-03-13                                   0.0001
# 2025-03-17                                   0.0001
# 2025-03-18                                   0.0001
# 2025-03-19                                   0.0001
# ...                                             ...
# 2025-12-29                                   0.0001
# 2025-12-30                                   0.0001
# 2025-12-31                                   0.0001
# 2026-01-01                                   0.0001
# 2026-01-02                                   0.0001
#
#             bounded_valuation_score_log_price_HDFCGOLD.NS  \
# Date
# 2025-03-12                                           -1.0
# 2025-03-13                                           -1.0
# 2025-03-17                                           -1.0
# 2025-03-18                                           -1.0
# 2025-03-19                                           -1.0
# ...                                                   ...
# 2025-12-29                                           -1.0
# 2025-12-30                                           -1.0
# 2025-12-31                                           -1.0
# 2026-01-01                                           -1.0
# 2026-01-02                                           -1.0
#
#             valuation_score_log_price_HDFCGOLD.NS
# Date
# 2025-03-12                                 0.0001
# 2025-03-13                                 0.0001
# 2025-03-17                                 0.0001
# 2025-03-18                                 0.0001
# 2025-03-19                                 0.0001
# ...                                           ...
# 2025-12-29                                 0.0001
# 2025-12-30                                 0.0001
# 2025-12-31                                 0.0001
# 2026-01-01                                 0.0001
# 2026-01-02                                 0.0001
#
# [199 rows x 12 columns]
