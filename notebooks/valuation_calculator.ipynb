# %% [markdown]
# # 0. Configs and Imports

# %% [markdown]
# ## 0.1. Imports

# %%
# External Libraries imports
import pandas as pd

# Specialised imports
from src.utils.file_operators import load_yaml
from src.computation.valuation import raw_valuation_score_computation

# %% [markdown]
# ## 0.2. Configuration Filepath & Configuration Dictionary

# %%
conf_path = "C:/Users/sharv/Documents/Sharvil/Projects/AutoWeight/config-sd.yaml"

# %%
config = load_yaml(conf_path)

# %% [markdown]
# # 1. View the Tickers & set configuration

# %%
# Print the tickers defined in the config
ticker_list = config['config']['data']['tickers']

# Print the window and volitility_indicator defined in the config
window = config['config']['data']['window_in_days']
volatility_indicator = config['config']['data']['vix']

# %%
print("The tickers in the config list are:")

for idx, ticker in enumerate(ticker_list):
    print(f"    {idx+1}. {ticker}")

print(f"The window of data to evaluate is `{window}` days")

print(f"The volatility indicator used is `{volatility_indicator}`")
# Out:
# The tickers in the config list are:
#     1. HDFCSML250.NS
#     2. HDFCGOLD.NS
#     3. HDFCNEXT50.NS
# The window of data to evaluate is `900` days
# The volatility indicator used is `^INDIAVIX`

# %% [markdown]
# # 2. View the Correlation Parameters from Data

# %%
config['config']['parameters']['valuation']
# Out:
# {'method': 'log_return_z_score',
#  'window_in_days': 400,
#  'metric': 'adj_close',
#  'apply_bounding': True}

# %% [markdown]
# # 3. Calculate Correlation Values

# %%
correlation_results = raw_valuation_score_computation(
    config_path=conf_path,
    save_data=True,
    verbose=True
)
# Out:
# INFO: Starting Valuation Pipeline.
# INFO: Using price metric adj_close
# INFO: Caculated 'returns' from the adj_close price metric
# INFO: Caculated 'log_returns' from the 'returns' metric
# INFO: Computing Valuation scores:
# INFO:     Computing valuation score for column: log_returns_HDFCGOLD.NS
# INFO:     Computing valuation score for column: log_returns_HDFCNEXT50.NS
# INFO:     Merging valuation score for column: log_returns_HDFCNEXT50.NS
# INFO:        Initial DF shape: (595, 13)
# INFO:        Final DF shape: (595, 13)
#
# INFO:     Computing valuation score for column: log_returns_HDFCSML250.NS
# INFO:     Merging valuation score for column: log_returns_HDFCSML250.NS
# INFO:        Initial DF shape: (595, 15)
# INFO:        Final DF shape: (595, 15)
#
# SUCCESS: Valuation Scores computed and merged into a single DataFrame
# INFO: Saving 'valuation_input_matrix' DataFrames
# SUCCESS: Saved 'valuation_input_matrix' DataFrames
# INFO: Saving 'valuation_scores_full_matrix' DataFrames
# SUCCESS: Saved price only 'valuation_scores_full_matrix' DataFrames
# INFO: Saving log_returns only 'valuation_scores_full_matrix' DataFrames
# SUCCESS: Saved log_price only 'valuation_scores_full_matrix' DataFrames
# INFO: Saving 'valuation_scores_latest_matrix' DataFrames
# SUCCESS: Saved price only 'valuation_scores_latest_matrix' DataFrames
# INFO: Saving log_returns only 'valuation_scores_latest_matrix' DataFrames
# SUCCESS: Saved log_price only 'valuation_scores_latest_matrix' DataFrames
# SUCCESS: All DataFrames saved successfully
# SUCCESS: Valuation Pipeline Run Successfully.

# %%
correlation_results['valuation_score_df']
# Out:
#             price_HDFCSML250.NS  price_HDFCGOLD.NS  price_HDFCNEXT50.NS  \
# Date
# 2025-03-18           142.259995          76.300003            60.169998
# 2025-03-19           148.960007          76.360001            62.750000
# 2025-03-20           149.830002          76.720001            63.169998
# 2025-03-21           152.979996          76.279999            63.650002
# 2025-03-24           154.720001          75.650002            64.400002
# ...                         ...                ...                  ...
# 2025-12-29           166.169998         116.870003            69.730003
# 2025-12-30           165.929993         114.940002            69.949997
# 2025-12-31           167.710007         113.709999            70.599998
# 2026-01-01           167.529999         114.099998            70.959999
# 2026-01-02           168.850006         115.449997            71.489998
#
#             returns_HDFCSML250.NS  returns_HDFCGOLD.NS  returns_HDFCNEXT50.NS  \
# Date
# 2025-03-18               1.000000             1.007926               1.000000
# 2025-03-19               1.047097             1.000786               1.042879
# 2025-03-20               1.005840             1.004715               1.006693
# 2025-03-21               1.021024             0.994265               1.007599
# 2025-03-24               1.011374             0.991741               1.011783
# ...                           ...                  ...                    ...
# 2025-12-29               0.994613             0.990760               0.992174
# 2025-12-30               0.998556             0.983486               1.003155
# 2025-12-31               1.010728             0.989299               1.009292
# 2026-01-01               0.998927             1.003430               1.005099
# 2026-01-02               1.007879             1.011832               1.007469
#
#             log_returns_HDFCSML250.NS  log_returns_HDFCGOLD.NS  \
# Date
# 2025-03-18                   0.000000                 0.007895
# 2025-03-19                   0.046022                 0.000786
# 2025-03-20                   0.005823                 0.004703
# 2025-03-21                   0.020806                -0.005752
# 2025-03-24                   0.011310                -0.008293
# ...                               ...                      ...
# 2025-12-29                  -0.005402                -0.009283
# 2025-12-30                  -0.001445                -0.016652
# 2025-12-31                   0.010670                -0.010759
# 2026-01-01                  -0.001074                 0.003424
# 2026-01-02                   0.007848                 0.011762
#
#             log_returns_HDFCNEXT50.NS  \
# Date
# 2025-03-18                   0.000000
# 2025-03-19                   0.041985
# 2025-03-20                   0.006671
# 2025-03-21                   0.007570
# 2025-03-24                   0.011714
# ...                               ...
# 2025-12-29                  -0.007857
# 2025-12-30                   0.003150
# 2025-12-31                   0.009249
# 2026-01-01                   0.005086
# 2026-01-02                   0.007441
#
#             valuation_score_log_returns_HDFCGOLD.NS  \
# Date
# 2025-03-18                               -51.098751
# 2025-03-19                               -52.559543
# 2025-03-20                               -53.518254
# 2025-03-21                               -52.281297
# 2025-03-24                               -51.369214
# ...                                             ...
# 2025-12-29                               -62.720232
# 2025-12-30                               -60.888598
# 2025-12-31                               -58.861740
# 2026-01-01                               -58.457191
# 2026-01-02                               -59.779258
#
#             bounded_valuation_score_log_returns_HDFCGOLD.NS  \
# Date
# 2025-03-18                                             -1.0
# 2025-03-19                                             -1.0
# 2025-03-20                                             -1.0
# 2025-03-21                                             -1.0
# 2025-03-24                                             -1.0
# ...                                                     ...
# 2025-12-29                                             -1.0
# 2025-12-30                                             -1.0
# 2025-12-31                                             -1.0
# 2026-01-01                                             -1.0
# 2026-01-02                                             -1.0
#
#             valuation_score_log_returns_HDFCNEXT50.NS  \
# Date
# 2025-03-18                                  17.202727
# 2025-03-19                                  16.827896
# 2025-03-20                                  16.764143
# 2025-03-21                                  16.757739
# 2025-03-24                                  16.803721
# ...                                               ...
# 2025-12-29                                  -6.984000
# 2025-12-30                                  -5.532833
# 2025-12-31                                  -5.811041
# 2026-01-01                                  -5.946083
# 2026-01-02                                  -5.440557
#
#             bounded_valuation_score_log_returns_HDFCNEXT50.NS  \
# Date
# 2025-03-18                                           1.000000
# 2025-03-19                                           1.000000
# 2025-03-20                                           1.000000
# 2025-03-21                                           1.000000
# 2025-03-24                                           1.000000
# ...                                                       ...
# 2025-12-29                                          -0.999998
# 2025-12-30                                          -0.999969
# 2025-12-31                                          -0.999982
# 2026-01-01                                          -0.999986
# 2026-01-02                                          -0.999962
#
#             valuation_score_log_returns_HDFCSML250.NS  \
# Date
# 2025-03-18                                 -21.298059
# 2025-03-19                                 -24.630851
# 2025-03-20                                 -24.837376
# 2025-03-21                                 -26.079381
# 2025-03-24                                 -26.537980
# ...                                               ...
# 2025-12-29                                  -7.952786
# 2025-12-30                                  -6.564916
# 2025-12-31                                  -6.622381
# 2026-01-01                                  -6.011886
# 2026-01-02                                  -5.672227
#
#             bounded_valuation_score_log_returns_HDFCSML250.NS
# Date
# 2025-03-18                                          -1.000000
# 2025-03-19                                          -1.000000
# 2025-03-20                                          -1.000000
# 2025-03-21                                          -1.000000
# 2025-03-24                                          -1.000000
# ...                                                       ...
# 2025-12-29                                          -1.000000
# 2025-12-30                                          -0.999996
# 2025-12-31                                          -0.999996
# 2026-01-01                                          -0.999988
# 2026-01-02                                          -0.999976
#
# [196 rows x 15 columns]
