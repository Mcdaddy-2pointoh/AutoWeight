# %% [markdown]
# # 0. Configs and Imports

# %% [markdown]
# ## 0.1. Imports

# %%
# Imports for data fetch
from src.data_collectors.yahoo_fin_collector import fetch_data

# Imports for loading config
from src.utils.file_operators import load_yaml

# External Libraries imports
import yfinance as yf
import pandas as pd

# %% [markdown]
# ## 0.2. Configuration Filepath & Configuration Dictionary

# %%
conf_path = "C:/Users/sharv/Documents/Sharvil/Projects/AutoWeight/config-sd.yaml"

# %%
config = load_yaml(conf_path)

# %% [markdown]
# # 1. View the Tickers & set configuration

# %%
# Print the tickers defined in the config
ticker_list = config['config']['data']['tickers']

# Print the window and volitility_indicator defined in the config
window = config['config']['data']['window_in_days']
volatility_indicator = config['config']['data']['vix']

# %%
print("The tickers in the config list are:")

for idx, ticker in enumerate(ticker_list):
    print(f"    {idx+1}. {ticker}")

print(f"The window of data to evaluate is `{window}` days")

print(f"The volatility indicator used is `{volatility_indicator}`")
# Out:
# The tickers in the config list are:
#     1. HDFCSML250.NS
#     2. HDFCGOLD.NS
#     3. HDFCNEXT50.NS
#     4. AMBUJACEM.NS
#     5. ASIANPAINT.NS
#     6. EIDPARRY.NS
#     7. ETERNAL.NS
#     8. GMRAIRPORT.NS
#     9. HDFCBANK.NS
#     10. ABC.NS
#     11. ITC.NS
#     12. LLOYDSME.NS
#     13. NBCC.NS
#     14. OLECTRA.NS
#     15. PCBL.NS
# The window of data to evaluate is `900` days
# The volatility indicator used is `^INDIAVIX`

# %% [markdown]
# # 2. Fetch Data

# %%
ohlcv_data = fetch_data(
    config_path=conf_path,
    save_data=True,
    verbose=True
)
# Out:
# INFO: Downloading data for ticker: HDFCSML250.NS
# SUCCESS: Successfully downloaded data for: HDFCSML250.NS
# INFO: Processing data for ticker: HDFCSML250.NS
# SUCCESS: Successfully processed data for ticker: HDFCSML250.NS
#
# INFO: Downloading data for ticker: HDFCGOLD.NS
# SUCCESS: Successfully downloaded data for: HDFCGOLD.NS
# INFO: Processing data for ticker: HDFCGOLD.NS
# SUCCESS: Successfully processed data for ticker: HDFCGOLD.NS
#
# INFO: Downloading data for ticker: HDFCNEXT50.NS
# SUCCESS: Successfully downloaded data for: HDFCNEXT50.NS
# INFO: Processing data for ticker: HDFCNEXT50.NS
# SUCCESS: Successfully processed data for ticker: HDFCNEXT50.NS
#
# INFO: Downloading data for ticker: AMBUJACEM.NS
# SUCCESS: Successfully downloaded data for: AMBUJACEM.NS
# INFO: Processing data for ticker: AMBUJACEM.NS
# SUCCESS: Successfully processed data for ticker: AMBUJACEM.NS
#
# INFO: Downloading data for ticker: ASIANPAINT.NS
# SUCCESS: Successfully downloaded data for: ASIANPAINT.NS
# INFO: Processing data for ticker: ASIANPAINT.NS
# SUCCESS: Successfully processed data for ticker: ASIANPAINT.NS
#
# INFO: Downloading data for ticker: EIDPARRY.NS
# SUCCESS: Successfully downloaded data for: EIDPARRY.NS
# INFO: Processing data for ticker: EIDPARRY.NS
# SUCCESS: Successfully processed data for ticker: EIDPARRY.NS
#
# INFO: Downloading data for ticker: ETERNAL.NS
# SUCCESS: Successfully downloaded data for: ETERNAL.NS
# INFO: Processing data for ticker: ETERNAL.NS
# SUCCESS: Successfully processed data for ticker: ETERNAL.NS
#
# INFO: Downloading data for ticker: GMRAIRPORT.NS
# SUCCESS: Successfully downloaded data for: GMRAIRPORT.NS
# INFO: Processing data for ticker: GMRAIRPORT.NS
# SUCCESS: Successfully processed data for ticker: GMRAIRPORT.NS
#
# INFO: Downloading data for ticker: HDFCBANK.NS
# SUCCESS: Successfully downloaded data for: HDFCBANK.NS
# INFO: Processing data for ticker: HDFCBANK.NS
# SUCCESS: Successfully processed data for ticker: HDFCBANK.NS
#
# INFO: Downloading data for ticker: ABC.NS
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ABC.NS"}}}
# $ABC.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ABC.NS']: possibly delisted; no timezone found
# ERROR: Possible Delising or Incorrect Name for ticker: ABC.NS
#
# INFO: Downloading data for ticker: ITC.NS
# SUCCESS: Successfully downloaded data for: ITC.NS
# INFO: Processing data for ticker: ITC.NS
# SUCCESS: Successfully processed data for ticker: ITC.NS
#
# INFO: Downloading data for ticker: LLOYDSME.NS
# SUCCESS: Successfully downloaded data for: LLOYDSME.NS
# INFO: Processing data for ticker: LLOYDSME.NS
# SUCCESS: Successfully processed data for ticker: LLOYDSME.NS
#
# INFO: Downloading data for ticker: NBCC.NS
# SUCCESS: Successfully downloaded data for: NBCC.NS
# INFO: Processing data for ticker: NBCC.NS
# SUCCESS: Successfully processed data for ticker: NBCC.NS
#
# INFO: Downloading data for ticker: OLECTRA.NS
# SUCCESS: Successfully downloaded data for: OLECTRA.NS
# INFO: Processing data for ticker: OLECTRA.NS
# SUCCESS: Successfully processed data for ticker: OLECTRA.NS
#
# INFO: Downloading data for ticker: PCBL.NS
# SUCCESS: Successfully downloaded data for: PCBL.NS
# INFO: Processing data for ticker: PCBL.NS
# SUCCESS: Successfully processed data for ticker: PCBL.NS
#
# INFO: Saving data for all tickers:
# INFO:    1. HDFCSML250.NS
# INFO:    2. HDFCGOLD.NS
# INFO:    3. HDFCNEXT50.NS
# INFO:    4. AMBUJACEM.NS
# INFO:    5. ASIANPAINT.NS
# INFO:    6. EIDPARRY.NS
# INFO:    7. ETERNAL.NS
# INFO:    8. GMRAIRPORT.NS
# INFO:    9. HDFCBANK.NS
# INFO:    10. ABC.NS
# INFO:    11. ITC.NS
# INFO:    12. LLOYDSME.NS
# INFO:    13. NBCC.NS
# INFO:    14. OLECTRA.NS
# INFO:    15. PCBL.NS
# SUCCESS: Successfully saved data for tickers
# SUCCESS: fetch_data pipeline run completed
